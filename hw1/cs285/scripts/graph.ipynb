# %% [markdown]
# # Graph for Problem 1.3

# %%
import matplotlib.pyplot as plt

train_steps = [250, 500, 750, 1000, 1250, 1500]
average_return = [660, 2349, 4333, 4451, 4293, 4456]
std_return = [465.7, 1516, 127.1, 52.8, 543.5, 158.6]

plt.xlabel('train steps')
plt.ylabel('average return')
plt.title('hyperparameter sweep')
plt.errorbar(train_steps, average_return, yerr=std_return)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Graph for Problem

# %%
dagger_iter = range(20)
ant_return = [4451, 4585, 4712, 4460, 4619, 4617, 4773, 4650, 4104, 4643, 4683, 4723, 4764, 4762, 4739, 4039, 4626, 4725, 4688, 4741]
ant_std = [52.8, 83.54, 95.91, 54.35, 55.24, 54.2, 166.6, 92.2, 1441, 61.98, 33.18, 97.37, 20.26, 72.6, 61.85, 1497, 95.1, 52.46, 80.68, 58.56]
ant_expert = 4714
ant_bc = 4451


hopper_return = [972.7, 903.9, 1937, 2834, 3402, 3742, 3435, 3769, 3776, 3774, 3775, 3772, 3780, 3781, 3777, 3775, 3785, 3776, 3771, 3784]
hopper_std = [152.3, 127, 312.2, 580.8, 772.3, 12.23, 713, 10.24, 4.63, 11.46, 2.972, 3.341, 6.78, 1.57, 1.125, 2.272, 2.096, 4.964, 2.559, 2.776]
hopper_expert = 3773
hopper_bc = 972.7

plt.errorbar(dagger_iter, ant_return, yerr=ant_std, label='ant')
plt.axhline(ant_expert, 0, 20, label='ant expert', c='b')
plt.axhline(ant_bc, 0, 20, label='ant behavior cloning', c='c')
plt.errorbar(dagger_iter, hopper_return, yerr=hopper_std, label='hopper')
plt.axhline(hopper_expert, 0, 20, label='hopper expert', c='orange')
plt.axhline(hopper_bc, 0, 20, label='hopper behavior cloning', c='y')
plt.xlabel('DAgger iteration')
plt.ylabel('average_return')
plt.title('DAgger')
plt.legend()
